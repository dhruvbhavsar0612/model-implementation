# %% [markdown]
# ## Goal
# Learn to implement the model _f_ for linear regression with one variable

# %% [markdown]
# ## Tools
# * NumPy, a popular library for scientific computing
# * Matplotlib, a popular library for plotting and visualizing

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This lab will use a simple data set with only two data points - a house with 1000 square feet(sqft) sold for \\$300,000 and a house with 2000 square feet sold for \\$500,000. These two points will constitute our *data or training set*. In this lab, the units of size are 1000 sqft and the units of price are 1000s of dollars.
#
# | Size (1000 sqft)     | Price (1000s of dollars) |
# | -------------------| ------------------------ |
# | 1.0               | 300                      |
# | 2.0               | 500                      |

# %%
#x_train is the input variable 
#y_train is the target variable
x_train= np.array([1.0,2.0])
y_train= np.array([300.0,500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
print(f"x_train.shape: {x_train.shape}")
m=x_train.shape[0]
print(f"Number of training examples is :{m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is :2

# %%
#training examples
for i in range (0,2):
    x_i=x_train[i]
    y_i=y_train[i]
    print(f"(x^({i}),y^({i}))=({x_i},{y_i})")
# Out:
# (x^(0),y^(0))=(1.0,300.0)
# (x^(1),y^(1))=(2.0,500.0)

# %% [markdown]
# ## Plotting the data to understand their behaviour on scattered plot

# %%
plt.scatter(x_train, y_train, marker='x',c='r')
plt.title("Housing prices")
plt.ylabel("Prices(in 1000s of dollars)")
plt.xlabel("Area(in 1000s of squared feet)")
plt.show()

# %% [markdown]
# We can now present a model based on this as: f=w*x^i + b
# Lets start with a intuition w=100, b=100

# %%
w=100
b=100
print(f"W: {w}")
print(f"b: {b}")
# Out:
# W: 100
# b: 100

# %%
def compute_model_output(x,w,b):
    """
    Computes the output prediction of a linear model
    Args:
        x(ndarray(m,)):data, m examples
        w,b(scaler): model parameters
    Returns:
        f_wb (ndarray(m, )): model prediction
    """
    m=x.shape[0]
    f_wb=np.zeros(m)
    for i in range(m):
        f_wb[i]=w*x[i]+b
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train,w,b)

plt.plot(x_train, tmp_f_wb, c="b",label="Our prediction")
plt.scatter(x_train, y_train, marker='x', c='r',label="Actual Values")

plt.legend()
plt.show()

# %%
#here the w=100 and b=100 doesnt fit right for out data so,
w=200
tmp_f_wb = compute_model_output(x_train,w,b)

plt.plot(x_train, tmp_f_wb, c="b",label="Our prediction")
plt.scatter(x_train, y_train, marker='x', c='r',label="Actual Values")

plt.legend()
plt.show()

# %% [markdown]
# Found the perfect fit for the model, now let us try to predict the price of a house

# %%
x_i=1.2
cost_1200= w*x_i +b
print(f"${cost_1200:.0f},000")
# Out:
# $340,000
